# %%
#bagian 1
try:
    temperatur = int(input("Masukkan suhu tubuh: "))
    if temperatur >= 38:
        print("Anda demam")
    else:
        print("Anda tidak demam")
except:
    print("Format inputan anda salah, mohon input bertipe integer (angka)")
# Out:
# Masukkan suhu tubuh:  36
# Anda tidak demam

# %%
try:
    angka = int(input("Masukkan suatu bilangan: "))
    if angka > 0:
        print("Positif")
    elif angka < 0:
        print("Negatif")
    elif angka == 0:
        print("Nol")
except:
    print("Format inputan anda salah, mohon input bertipe integer (angka)")
# Out:
# Masukkan suatu bilangan:  56
# Positif

# %%
try:
    nilai = int(input("Inputkan suatu bilangan: "))
    print("Positif" if nilai % 2 == 0 else "negatif")
except:
    print("Input anda salah")
# Out:
# Inputkan suatu bilangan:  12
# Positif

# %%
try:
    nilai = int(input("Inputkan suatu bilangan: "))
    print("Positif" if nilai % 2 == 0 else "negatif")
except:
    print("Input anda salah")
# Out:
# Inputkan suatu bilangan:  66
# Positif

# %%
try:
    bulan = int(input("Masukan bulan (1-12) bertipe integer: "))
    if bulan == 1 or bulan == 3 or bulan == 5 or bulan == 7 == bulan == 8 or bulan == 10 or bulan == 12:
        print("Jumlah Hari 31")
    elif bulan == 4 or bulan == 6 or bulan == 9 or bulan == 11:
        print("Jumlah Hari 30")
    elif bulan > 12:
        print("Jumlah bulan harus benar")
    else:
        print("Jumlah Hari 29")
except:
    print("Inputan bulan tidak valid")
# Out:
# Masukan bulan (1-12) bertipe integer:  7
# Jumlah Hari 29

# %%
try:
    sisi1 = int(input("masukan Sisi 1: "))
    sisi2 = int(input("masukan Sisi 2: "))
    sisi3 = int(input("masukan Sisi 3: "))

    if sisi1 == sisi2 and sisi2 == sisi3 and sisi1 == sisi3:
        print("3 sisi sama")
    elif sisi1 == sisi2 or sisi2 == sisi3 or sisi1 == sisi3:
        print("2 sisi sama")
    else:
        print("Tidak ada yang sama")
except:
    print("Input yang anda masukan salah, mohon imputkan integer")
# Out:
# masukan Sisi 1:  14
# masukan Sisi 2:  18
# masukan Sisi 3:  11
# Tidak ada yang sama
