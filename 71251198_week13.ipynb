# %%
tA = (90, 90, 90, 90)

cek = True

for i in tA:
    if i != tA[0]:
        cek = False

print(cek)
# Out:
# True

# %%
data = ('MOSES MEROHITO', '71251198', 'PURWOKERTO, JAWA TENGAH')

print("NIM    :", data[1])
print("NAMA   :", data[0])
print("ALAMAT :", data[2])

nim_tuple = tuple(data[1])
print("\nNIM    :", nim_tuple)

nama_depan = tuple(data[0].split()[0])
print("NAMA DEPAN:", nama_depan[:])

nama_terbalik = tuple(reversed(data[0].split()))
print("NAMA TERBALIK:", nama_terbalik)
# Out:
# NIM    : 71251198
# NAMA   : MOSES MEROHITO
# ALAMAT : PURWOKERTO, JAWA TENGAH
#
# NIM    : ('7', '1', '2', '5', '1', '1', '9', '8')
# NAMA DEPAN: ('M', 'O', 'S', 'E', 'S')
# NAMA TERBALIK: ('MEROHITO', 'MOSES')

# %%
# Membuat file mbox-short.txt dengan output sesuai soal

data_email = """From a@a.com Sat Jan 5 04:10:11 2008
From b@b.com Sat Jan 5 04:11:11 2008
From c@c.com Sat Jan 5 04:12:11 2008
From d@d.com Sat Jan 5 06:10:11 2008
From e@e.com Sat Jan 5 07:10:11 2008
From f@f.com Sat Jan 5 09:10:11 2008
From g@g.com Sat Jan 5 09:11:11 2008
From h@h.com Sat Jan 5 10:10:11 2008
From i@i.com Sat Jan 5 10:11:11 2008
From j@j.com Sat Jan 5 10:12:11 2008
From k@k.com Sat Jan 5 11:10:11 2008
From l@l.com Sat Jan 5 11:11:11 2008
From m@m.com Sat Jan 5 11:12:11 2008
From n@n.com Sat Jan 5 11:13:11 2008
From o@o.com Sat Jan 5 11:14:11 2008
From p@p.com Sat Jan 5 11:15:11 2008
From q@q.com Sat Jan 5 14:10:11 2008
From r@r.com Sat Jan 5 15:10:11 2008
From s@s.com Sat Jan 5 15:11:11 2008
From t@t.com Sat Jan 5 16:10:11 2008
From u@u.com Sat Jan 5 16:11:11 2008
From v@v.com Sat Jan 5 16:12:11 2008
From w@w.com Sat Jan 5 16:13:11 2008
From x@x.com Sat Jan 5 17:10:11 2008
From y@y.com Sat Jan 5 17:11:11 2008
From z@z.com Sat Jan 5 18:10:11 2008
From aa@aa.com Sat Jan 5 19:10:11 2008"""

with open("mbox-short.txt", "w") as file:
    file.write(data_email)

print("File mbox-short.txt berhasil dibuat")
# Out:
# File mbox-short.txt berhasil dibuat

# %%
input_file = input("Enter a file name: ")

try:
    buka_file = open(input_file)
except:
    print("File tidak ditemukan.")
    quit()

hitung_jam = dict()

for line in buka_file:
    if line.startswith("From "):
        parts = line.split()
        waktu = parts[5]
        jam = waktu.split(":")[0]

        hitung_jam[jam] = hitung_jam.get(jam, 0) + 1

hasil = sorted(hitung_jam.items())
for jam, jumlah in hasil:
    print(jam, jumlah)
# Out:
# Enter a file name:  mbox-short.txt
# 04 3
# 06 1
# 07 1
# 09 2
# 10 3
# 11 6
# 14 1
# 15 2
# 16 4
# 17 2
# 18 1
# 19 1
